# %%
temperatur = 35

if temperatur != 30:
    print("It's a hot day")
else:
    print("It's not a hot day")
# Out:
# It's a hot day

# %%
temperatur = 35

if temperatur == 30:
    print("It's a hot day")
else:
    print("It's not a hot day")
# Out:
# It's not a hot day

# %%
name = input("what is your name? ")


if len(name) < 3:
    print("Name should be at least 3 characher long.")
elif len(name) > 50:
    print("Name can be maximum 50 characters long.")
else:
    print("Name looks good!")
# Out:
# Name should be at least 3 characher long.
