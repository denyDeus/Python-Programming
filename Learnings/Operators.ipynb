# %%
Yairo_Age = 2
Age_at_Kindergarten = 5
print(Yairo_Age == Age_at_Kindergarten)
# Out:
# False

# %%
Yairo_Age = 2
Age_at_Kindergarten = 5

if Yairo_Age < Age_at_Kindergarten:
    print("He should be in pre school")
# Out:
# He should be in pre school

# %%
Yairo_Age = 7
Age_at_Kindergarten = 5

if Yairo_Age < Age_at_Kindergarten:
    print("He should be in pre school")
else:
    print("He should be in kindergarten or other classes")
# Out:
# He should be in kindergarten or other classes
